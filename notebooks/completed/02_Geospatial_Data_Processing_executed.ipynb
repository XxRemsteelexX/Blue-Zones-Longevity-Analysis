# %% [markdown]
# # 🗺️ Geospatial Data Processing
#
# Processing geographic and spatial data for Blue Zones analysis.

# %%
# Setup
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load test data
df = pd.read_csv('../outputs/test_data_with_gravity.csv')
print("📊 Data loaded successfully!")
print(f"Shape: {df.shape}")
df.head()
# Out:
# 📊 Data loaded successfully!
# Shape: (25, 11)
#          name  latitude  longitude  elevation  life_expectancy  is_blue_zone  \
# 0      Nicoya      10.2      -85.4      200.0             83.7             1
# 1     Okinawa      26.3      127.9       50.0             85.5             1
# 2    Sardinia      40.1        9.4      300.0             84.8             1
# 3      Ikaria      37.6       26.2      400.0             84.1             1
# 4  Loma Linda      34.0     -117.3      350.0             82.9             1
#
#    effective_gravity  gravity_deviation  gravity_deviation_pct  \
# 0           9.801264          -0.005386              -0.054924
# 1           9.803404          -0.003246              -0.033105
# 2           9.804856          -0.001794              -0.018297
# 3           9.804113          -0.002537              -0.025866
# 4           9.803661          -0.002989              -0.030474
#
#    equatorial_distance  lifetime_gravity_exposure
# ...

# %%
# Basic visualization
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(df['longitude'], df['latitude'], c=df['effective_gravity'], cmap='viridis')
plt.colorbar(label='Gravity (m/s²)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Global Gravity Distribution')

plt.subplot(1, 2, 2)
blue_zones = df[df['is_blue_zone'] == 1]
others = df[df['is_blue_zone'] == 0]

plt.scatter(others['effective_gravity'], others['life_expectancy'], alpha=0.6, label='Other Regions')
plt.scatter(blue_zones['effective_gravity'], blue_zones['life_expectancy'], 
           color='red', s=100, label='Blue Zones', marker='*')
plt.xlabel('Effective Gravity (m/s²)')
plt.ylabel('Life Expectancy')
plt.title('Gravity vs Longevity')
plt.legend()

plt.tight_layout()
plt.show()

print("🎉 Geospatial analysis complete!")
# Out:
# 🎉 Geospatial analysis complete!
